# %%
import function.phy_funct as phy
import matplotlib.pyplot as plt

# %%
x , y = phy.projectile(0.01,500)

plt.plot(x , y)
plt.show()

# %%
y
# Out:
# array([ 0.000000e+00,  5.000000e-02,  9.902000e-02,  1.470600e-01,
#         1.941200e-01,  2.402000e-01,  2.853000e-01,  3.294200e-01,
#         3.725600e-01,  4.147200e-01,  4.559000e-01,  4.961000e-01,
#         5.353200e-01,  5.735600e-01,  6.108200e-01,  6.471000e-01,
#         6.824000e-01,  7.167200e-01,  7.500600e-01,  7.824200e-01,
#         8.138000e-01,  8.442000e-01,  8.736200e-01,  9.020600e-01,
#         9.295200e-01,  9.560000e-01,  9.815000e-01,  1.006020e+00,
#         1.029560e+00,  1.052120e+00,  1.073700e+00,  1.094300e+00,
#         1.113920e+00,  1.132560e+00,  1.150220e+00,  1.166900e+00,
#         1.182600e+00,  1.197320e+00,  1.211060e+00,  1.223820e+00,
#         1.235600e+00,  1.246400e+00,  1.256220e+00,  1.265060e+00,
#         1.272920e+00,  1.279800e+00,  1.285700e+00,  1.290620e+00,
#         1.294560e+00,  1.297520e+00,  1.299500e+00,  1.300500e+00,
#         1.300520e+00,  1.299560e+00,  1.297620e+00,  1.294700e+00,
# ...
